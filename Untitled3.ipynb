# %%
mydict={"c":"Easy","c++":"moderate","java":"tough","python":"cool"}
print(mydict)
# Out:
# {'c': 'Easy', 'c++': 'moderate', 'java': 'tough', 'python': 'cool'}

# %%
del mydict["c"]
print(mydict)
# Out:
# {'c++': 'moderate', 'java': 'tough', 'python': 'cool'}

# %%
del mydict["c++"]
print(mydict)
# Out:
# {'java': 'tough', 'python': 'cool'}
